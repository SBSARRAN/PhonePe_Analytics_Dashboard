# %%
# Extracting Map_Transaction from Phone_Pay_pluse
import os
path_Map_Trans = "C:/Phone_pay/pulse/data/map/transaction/hover/country/india/state/"
Agg_state_list=os.listdir(path_Map_Trans)
Agg_state_list
# Out:
# ['andaman-&-nicobar-islands',
#  'andhra-pradesh',
#  'arunachal-pradesh',
#  'assam',
#  'bihar',
#  'chandigarh',
#  'chhattisgarh',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'delhi',
#  'goa',
#  'gujarat',
#  'haryana',
#  'himachal-pradesh',
#  'jammu-&-kashmir',
#  'jharkhand',
#  'karnataka',
#  'kerala',
#  'ladakh',
#  'lakshadweep',
#  'madhya-pradesh',
#  'maharashtra',
#  'manipur',
#  'meghalaya',
#  'mizoram',
#  'nagaland',
#  'odisha',
#  'puducherry',
#  'punjab',
#  'rajasthan',
#  'sikkim',
#  'tamil-nadu',
#  'telangana',
#  'tripura',
#  'uttar-pradesh',
#  'uttarakhand',
#  'west-bengal']

# %%
import pandas as pd
import json
import os

clm={'State':[], 'Year':[],'Quater':[],'Map_Transacion_District_Name':[], 'Map_Transacion_count':[], 'Map_Transacion_amount':[]}

for i in Agg_state_list:
    p_i=path_Map_Trans+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['hoverDataList']:
              Name=z['name']
              count=z['metric'][0]['count']
              amount=z['metric'][0]['amount']
              clm['Map_Transacion_District_Name'].append(Name)
              clm['Map_Transacion_count'].append(count)
              clm['Map_Transacion_amount'].append(amount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Map_Trans=pd.DataFrame(clm)

# %%
Map_Trans
# Out:
#                            State  Year  Quater  \
# 0      andaman-&-nicobar-islands  2018       1
# 1      andaman-&-nicobar-islands  2018       1
# 2      andaman-&-nicobar-islands  2018       1
# 3      andaman-&-nicobar-islands  2018       2
# 4      andaman-&-nicobar-islands  2018       2
# ...                          ...   ...     ...
# 20599                west-bengal  2024       4
# 20600                west-bengal  2024       4
# 20601                west-bengal  2024       4
# 20602                west-bengal  2024       4
# 20603                west-bengal  2024       4
#
#             Map_Transacion_District_Name  Map_Transacion_count  \
# 0      north and middle andaman district                   442
# 1                 south andaman district                  5688
# 2                      nicobars district                   528
# 3      north and middle andaman district                   825
# 4                 south andaman district                  9395
# ...

# %%
import mysql.connector
mydb = mysql.connector.connect(
        host = "localhost",
        user = "root",
        password = "12345",
        database = "Phone_Pay",
        autocommit = True)
mycursor = mydb.cursor()

# %%
Map_Trans.dtypes
# Out:
# State                            object
# Year                             object
# Quater                            int64
# Map_Transacion_District_Name     object
# Map_Transacion_count              int64
# Map_Transacion_amount           float64
# dtype: object

# %%
mycursor.execute("create table Map_Trans (State varchar (50), Year YEAR(4),Quater int, Map_Transaction_District_Name varchar (100), Map_Transaction_Count int, Map_Transaction_amount DECIMAL(20,2))")

# %%
values = [tuple(x) for x in Map_Trans.to_numpy()]
values
# Out:
# [('andaman-&-nicobar-islands',
#   '2018',
#   1,
#   'north and middle andaman district',
#   442,
#   931663.0770939873),
#  ('andaman-&-nicobar-islands',
#   '2018',
#   1,
#   'south andaman district',
#   5688,
#   12560249.34366581),
#  ('andaman-&-nicobar-islands',
#   '2018',
#   1,
#   'nicobars district',
#   528,
#   1139848.801225994),
#  ('andaman-&-nicobar-islands',
#   '2018',
#   2,
#   'north and middle andaman district',
#   825,
#   1317863.0834906558),
#  ('andaman-&-nicobar-islands',
#   '2018',
#   2,
#   'south andaman district',
#   9395,
#   23948235.51634325),
#  ('andaman-&-nicobar-islands',
#   '2018',
#   2,
#   'nicobars district',
#   1120,
#   3072436.9081196385),
#  ('andaman-&-nicobar-islands',
#   '2018',
#   3,
#   'north and middle andaman district',
#   1283,
#   4901529.518499676),
#  ('andaman-&-nicobar-islands',
#   '2018',
#   3,
#   'south andaman district',
#   13511,
#   44268112.46425246),
#  ('andaman-&-nicobar-islands',
#   '2018',
# ...

# %%
sql = """insert into Map_Trans (State , Year ,Quater , Map_Transaction_District_Name , Map_Transaction_Count , Map_Transaction_amount )
values (%s,%s,%s,%s,%s,%s)"""

# %%
mycursor.executemany(sql,values)

# %%
# Extracting Map_Insurance from Phone_Pay_pluse
import os
path_Map_Insu = "C:/Phone_pay/pulse/data/map/insurance/hover/country/india/state/"
Agg_state_list=os.listdir(path_Map_Insu)
Agg_state_list
# Out:
# ['andaman-&-nicobar-islands',
#  'andhra-pradesh',
#  'arunachal-pradesh',
#  'assam',
#  'bihar',
#  'chandigarh',
#  'chhattisgarh',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'delhi',
#  'goa',
#  'gujarat',
#  'haryana',
#  'himachal-pradesh',
#  'jammu-&-kashmir',
#  'jharkhand',
#  'karnataka',
#  'kerala',
#  'ladakh',
#  'lakshadweep',
#  'madhya-pradesh',
#  'maharashtra',
#  'manipur',
#  'meghalaya',
#  'mizoram',
#  'nagaland',
#  'odisha',
#  'puducherry',
#  'punjab',
#  'rajasthan',
#  'sikkim',
#  'tamil-nadu',
#  'telangana',
#  'tripura',
#  'uttar-pradesh',
#  'uttarakhand',
#  'west-bengal']

# %%
import pandas as pd
import json
import os

clm={'State':[], 'Year':[],'Quater':[],'Map_Insurance_District_Name':[], 'Map_Insurance_count':[], 'Map_Insurance_amount':[]}

for i in Agg_state_list:
    p_i=path_Map_Insu+i+"/"
    Agg_yr=os.listdir(p_i)
    for j in Agg_yr:
        p_j=p_i+j+"/"
        Agg_yr_list=os.listdir(p_j)
        for k in Agg_yr_list:
            p_k=p_j+k
            Data=open(p_k,'r')
            D=json.load(Data)
            for z in D['data']['hoverDataList']:
              Name=z['name']
              count=z['metric'][0]['count']
              amount=z['metric'][0]['amount']
              clm['Map_Insurance_District_Name'].append(Name)
              clm['Map_Insurance_count'].append(count)
              clm['Map_Insurance_amount'].append(amount)
              clm['State'].append(i)
              clm['Year'].append(j)
              clm['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Map_Insurance=pd.DataFrame(clm)

# %%
Map_Insurance
# Out:
#                            State  Year  Quater  \
# 0      andaman-&-nicobar-islands  2020       2
# 1      andaman-&-nicobar-islands  2020       2
# 2      andaman-&-nicobar-islands  2020       3
# 3      andaman-&-nicobar-islands  2020       3
# 4      andaman-&-nicobar-islands  2020       3
# ...                          ...   ...     ...
# 13871                west-bengal  2024       4
# 13872                west-bengal  2024       4
# 13873                west-bengal  2024       4
# 13874                west-bengal  2024       4
# 13875                west-bengal  2024       4
#
#              Map_Insurance_District_Name  Map_Insurance_count  \
# 0                 south andaman district                    3
# 1                      nicobars district                    3
# 2      north and middle andaman district                    1
# 3                 south andaman district                   35
# 4                      nicobars district                    5
# ...

# %%
Map_Insurance.dtypes
# Out:
# State                           object
# Year                            object
# Quater                           int64
# Map_Insurance_District_Name     object
# Map_Insurance_count              int64
# Map_Insurance_amount           float64
# dtype: object

# %%
mycursor.execute("create table Map_Insurance (State varchar (50),Year YEAR(4),Quater int, Map_Insurance_District_Name varchar (100),Map_Insurance_count int,Map_Insurance_amount Decimal(20,2) )")

# %%
values = [tuple(x) for x in Map_Insurance.to_numpy()]
values
# Out:
# [('andaman-&-nicobar-islands', '2020', 2, 'south andaman district', 3, 795.0),
#  ('andaman-&-nicobar-islands', '2020', 2, 'nicobars district', 3, 565.0),
#  ('andaman-&-nicobar-islands',
#   '2020',
#   3,
#   'north and middle andaman district',
#   1,
#   281.0),
#  ('andaman-&-nicobar-islands',
#   '2020',
#   3,
#   'south andaman district',
#   35,
#   13651.0),
#  ('andaman-&-nicobar-islands', '2020', 3, 'nicobars district', 5, 1448.0),
#  ('andaman-&-nicobar-islands',
#   '2020',
#   4,
#   'north and middle andaman district',
#   13,
#   17734.0),
#  ('andaman-&-nicobar-islands',
#   '2020',
#   4,
#   'south andaman district',
#   109,
#   137494.0),
#  ('andaman-&-nicobar-islands', '2020', 4, 'nicobars district', 2, 2747.0),
#  ('andaman-&-nicobar-islands',
#   '2021',
#   1,
#   'north and middle andaman district',
#   48,
#   63978.0),
#  ('andaman-&-nicobar-islands',
#   '2021',
#   1,
#   'south andaman district',
#   164,
#   167044.0),
# ...

# %%
sql = """ insert into Map_Insurance (State ,Year ,Quater , Map_Insurance_District_Name ,Map_Insurance_count ,Map_Insurance_amount) values
(%s,%s,%s,%s,%s,%s)"""

# %%
mycursor.executemany(sql,values)

# %%
# Extracting Map_Users from Phone_Pay_pluse
import os
path_Map_Users = "C:/Phone_pay/pulse/data/map/user/hover/country/india/state/"
Agg_state_list=os.listdir(path_Map_Users)
Agg_state_list
# Out:
# ['andaman-&-nicobar-islands',
#  'andhra-pradesh',
#  'arunachal-pradesh',
#  'assam',
#  'bihar',
#  'chandigarh',
#  'chhattisgarh',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'delhi',
#  'goa',
#  'gujarat',
#  'haryana',
#  'himachal-pradesh',
#  'jammu-&-kashmir',
#  'jharkhand',
#  'karnataka',
#  'kerala',
#  'ladakh',
#  'lakshadweep',
#  'madhya-pradesh',
#  'maharashtra',
#  'manipur',
#  'meghalaya',
#  'mizoram',
#  'nagaland',
#  'odisha',
#  'puducherry',
#  'punjab',
#  'rajasthan',
#  'sikkim',
#  'tamil-nadu',
#  'telangana',
#  'tripura',
#  'uttar-pradesh',
#  'uttarakhand',
#  'west-bengal']

# %%
import pandas as pd
import json
import os

clm = {'State': [], 'Year': [], 'Quater': [], 'Map_District_Users': [], 'Map_Registered_Users': [],'Map_AppOpens_Users': []}

for i in Agg_state_list:   # Each state
    p_i = path_Map_Users + i + "/"
    Agg_yr = os.listdir(p_i)
    
    for j in Agg_yr:   # Each year
        p_j = p_i + j + "/"
        Agg_yr_list = os.listdir(p_j)
        
        for k in Agg_yr_list:   # Each quarter file
            p_k = p_j + k
            with open(p_k, 'r') as Data:
                D = json.load(Data)
                print(D)
            
            if "data" in D and "hoverData" in D["data"]:
                 for district, values in D["data"]["hoverData"].items():
                    clm['Map_District_Users'].append(district)
                    clm['Map_Registered_Users'].append(values.get('registeredUsers', 0))
                    clm['Map_AppOpens_Users'].append(values.get('appOpens', 0))
                    clm['State'].append(i)
                    clm['Year'].append(j)
                    clm['Quater'].append(int(k.strip('.json')))
#Succesfully created a dataframe
Map_Users=pd.DataFrame(clm)
# Out:
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverData': {'north and middle andaman district': {'registeredUsers': 632, 'appOpens': 0}, 'south andaman district': {'registeredUsers': 5846, 'appOpens': 0}, 'nicobars district': {'registeredUsers': 262, 'appOpens': 0}}}, 'responseTimestamp': 1630502911500}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverData': {'north and middle andaman district': {'registeredUsers': 911, 'appOpens': 0}, 'south andaman district': {'registeredUsers': 8143, 'appOpens': 0}, 'nicobars district': {'registeredUsers': 351, 'appOpens': 0}}}, 'responseTimestamp': 1630502911544}
# {'success': True, 'code': 'SUCCESS', 'data': {'hoverData': {'north and middle andaman district': {'registeredUsers': 1208, 'appOpens': 0}, 'south andaman district': {'registeredUsers': 10474, 'appOpens': 0}, 'nicobars district': {'registeredUsers': 467, 'appOpens': 0}}}, 'responseTimestamp': 1630502911590}
# ...

# %%
Map_Users
# Out:
#                            State  Year  Quater  \
# 0      andaman-&-nicobar-islands  2018       1
# 1      andaman-&-nicobar-islands  2018       1
# 2      andaman-&-nicobar-islands  2018       1
# 3      andaman-&-nicobar-islands  2018       2
# 4      andaman-&-nicobar-islands  2018       2
# ...                          ...   ...     ...
# 20603                west-bengal  2024       4
# 20604                west-bengal  2024       4
# 20605                west-bengal  2024       4
# 20606                west-bengal  2024       4
# 20607                west-bengal  2024       4
#
#                       Map_District_Users  Map_Registered_Users  \
# 0      north and middle andaman district                   632
# 1                 south andaman district                  5846
# 2                      nicobars district                   262
# 3      north and middle andaman district                   911
# 4                 south andaman district                  8143
# ...

# %%
Map_Users.dtypes
# Out:
# State                   object
# Year                    object
# Quater                   int64
# Map_District_Users      object
# Map_Registered_Users     int64
# Map_AppOpens_Users       int64
# dtype: object

# %%
mycursor.execute("create Table Map_Users (State Varchar (50),Year YEAR(4),Quater int,Map_District_Users Varchar (50),Map_Registered_Users int,Map_AppOpens_Users int)")

# %%
sql = """insert into Map_users (State, Year,Quater,Map_District_Users,Map_Registered_Users,Map_AppOpens_Users)
values (%s,%s,%s,%s,%s,%s)"""

# %%
values = [tuple(x) for x in Map_Users.to_numpy()]
values
# Out:
# [('andaman-&-nicobar-islands',
#   '2018',
#   1,
#   'north and middle andaman district',
#   632,
#   0),
#  ('andaman-&-nicobar-islands', '2018', 1, 'south andaman district', 5846, 0),
#  ('andaman-&-nicobar-islands', '2018', 1, 'nicobars district', 262, 0),
#  ('andaman-&-nicobar-islands',
#   '2018',
#   2,
#   'north and middle andaman district',
#   911,
#   0),
#  ('andaman-&-nicobar-islands', '2018', 2, 'south andaman district', 8143, 0),
#  ('andaman-&-nicobar-islands', '2018', 2, 'nicobars district', 351, 0),
#  ('andaman-&-nicobar-islands',
#   '2018',
#   3,
#   'north and middle andaman district',
#   1208,
#   0),
#  ('andaman-&-nicobar-islands', '2018', 3, 'south andaman district', 10474, 0),
#  ('andaman-&-nicobar-islands', '2018', 3, 'nicobars district', 467, 0),
#  ('andaman-&-nicobar-islands',
#   '2018',
#   4,
#   'north and middle andaman district',
#   1553,
#   0),
#  ('andaman-&-nicobar-islands', '2018', 4, 'south andaman district', 13133, 0),
# ...

# %%
mycursor.executemany(sql,values)
